# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin
import concurrent.futures
######################################################################
# --------------------------------------------------------
# Created by Melissa Sim
# ---------------------------------------------------------
######################################################################
data_folder = '../dataset/'
base_folder = 'mg_0068/'

# URL of the directory containing the files
base_url = 'https://pds-geosciences.wustl.edu/mgn/mgn-v-rdrs-5-midr-full-res-v1/' + base_folder

# Create a directory to save the files
os.makedirs(data_folder + base_folder, exist_ok=True)

# Function to download a file
def download_file(url):
    after_base = url.split(base_folder)[1]
    folders = after_base.split('/')
    if len(folders) > 1:
        os.makedirs(data_folder + base_folder + folders[0], exist_ok=True)
    try:
        filename = data_folder + base_folder + after_base
        with requests.get(url, stream=True) as r:
            r.raise_for_status()
            with open(filename, 'wb') as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
        print(f'Successfully downloaded {filename}')
    except requests.HTTPError as e:
        print(f'Failed to download {url}: {e}')
    return filename

def recursive_download(base_link):
    response = requests.get(base_link)
    soup = BeautifulSoup(response.text, 'html.parser')
    pre = soup.find_all("pre")[0]
    links = pre.find_all("a")[1:]
    
    file_urls = []
    folder_links = []

    for link in links:
        href = link.get('href')
        if href and not href.endswith('/'):
            file_url = urljoin(base_url, base_link)
            file_url = urljoin(file_url, href)
            file_urls.append(file_url)
        elif href and href.endswith('/'):
            new_link = urljoin(base_link, href)
            folder_links.append(new_link)
    
    # Download files concurrently
    with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
        executor.map(download_file, file_urls)
    
    # Recursively process folders
    for folder_link in folder_links:
        recursive_download(folder_link)

recursive_download(base_url)
# Out:
# Successfully downloaded ../dataset/mg_0068/voldesc.sfd
# Successfully downloaded ../dataset/mg_0068/geo.lbl
# Successfully downloaded ../dataset/mg_0068/aareadme.txt
# Successfully downloaded ../dataset/mg_0068/mcumcomm.txt
# Successfully downloaded ../dataset/mg_0068/geo.tab
# Successfully downloaded ../dataset/mg_0068/f05s205/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff05.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff06.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff02.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff03.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff01.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff07.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff04.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff06.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff08.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/browse.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff09.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff10.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff11.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff12.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff15.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff05.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff17.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff13.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff14.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff19.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff18.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff20.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff23.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff24.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff21.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff22.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff26.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff27.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff25.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff16.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff29.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff28.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff32.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff30.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff31.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff34.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff35.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff36.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff39.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff42.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff40.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff33.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff43.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff43.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff38.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff39.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff44.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff45.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff46.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff41.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff41.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff45.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff47.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff44.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff46.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff48.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff49.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff47.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff50.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff48.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff51.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff49.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff52.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff50.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff53.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff51.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff54.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff52.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff55.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff56.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff55.img
# Successfully downloaded ../dataset/mg_0068/f05s205/frame.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/ff53.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff54.img
# Successfully downloaded ../dataset/mg_0068/f05s205/frame.tab
# Successfully downloaded ../dataset/mg_0068/f05s205/ff40.img
# Successfully downloaded ../dataset/mg_0068/f05s205/geom.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/geom.tab
# Successfully downloaded ../dataset/mg_0068/f05s205/ff56.img
# Successfully downloaded ../dataset/mg_0068/f05s205/hist.lbl
# Successfully downloaded ../dataset/mg_0068/f05s205/hist.tab
# Successfully downloaded ../dataset/mg_0068/f05s205/ff37.img
# Successfully downloaded ../dataset/mg_0068/f05s205/ff42.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff06.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff05.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff03.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff05.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff07.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff01.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff04.img
# Successfully downloaded ../dataset/mg_0068/f10s115/browse.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff08.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff06.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff02.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff11.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff15.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff16.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff10.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff17.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff12.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff18.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff14.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff20.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff19.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff23.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff09.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff25.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff24.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff27.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff29.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff28.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff30.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff31.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff13.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff26.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff21.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff22.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff32.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff33.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff34.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff39.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff35.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff40.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff41.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff42.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff37.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff36.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff38.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff39.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff40.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff41.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff43.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff44.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff45.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff42.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff43.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff46.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff48.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff47.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff49.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff46.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff44.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff50.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff45.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff48.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff51.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff52.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff50.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff53.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff51.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff55.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff49.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff54.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff56.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff47.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff54.img
# Successfully downloaded ../dataset/mg_0068/f10s115/frame.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff53.img
# Successfully downloaded ../dataset/mg_0068/f10s115/frame.tab
# Successfully downloaded ../dataset/mg_0068/f10s115/geom.tab
# Successfully downloaded ../dataset/mg_0068/f10s115/geom.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/ff56.img
# Successfully downloaded ../dataset/mg_0068/f10s115/hist.lbl
# Successfully downloaded ../dataset/mg_0068/f10s115/hist.tab
# Successfully downloaded ../dataset/mg_0068/f10s115/ff55.img
# Successfully downloaded ../dataset/mg_0068/f10s115/ff52.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff05.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff06.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff04.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff01.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/browse.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff03.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff02.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff08.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff05.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff12.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff11.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff09.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff13.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff07.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff15.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff16.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff19.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff17.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff18.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff21.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff20.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff24.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff22.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff23.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff25.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff27.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff26.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff06.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff28.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff30.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff33.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff32.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff34.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff35.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff29.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff39.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff37.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff40.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff38.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff41.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff42.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff36.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff41.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff40.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff43.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff39.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff42.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff43.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff44.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff45.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff46.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff44.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff47.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff48.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff45.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff49.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff46.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff50.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff47.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff51.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff10.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff52.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff53.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff49.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff50.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff31.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff48.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff54.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff14.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff55.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff52.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff53.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff51.img
# Successfully downloaded ../dataset/mg_0068/f15s174/ff56.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff54.img
# Successfully downloaded ../dataset/mg_0068/f15s174/frame.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/frame.tab
# Successfully downloaded ../dataset/mg_0068/f15s174/geom.tab
# Successfully downloaded ../dataset/mg_0068/f15s174/geom.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff55.img
# Successfully downloaded ../dataset/mg_0068/f15s174/hist.tab
# Successfully downloaded ../dataset/mg_0068/f15s174/hist.lbl
# Successfully downloaded ../dataset/mg_0068/f15s174/ff56.img
# Successfully downloaded ../dataset/mg_0068/f25n119/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff05.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff06.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff03.img
# Successfully downloaded ../dataset/mg_0068/f25n119/browse.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff04.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff06.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff02.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff05.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff08.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff09.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff10.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff11.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff12.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff13.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff07.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff14.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff16.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff17.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff18.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff20.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff15.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff21.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff22.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff24.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff23.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff26.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff30.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff31.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff25.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff28.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff27.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff32.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff33.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff19.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff36.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff39.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff40.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff38.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff34.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff39.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff41.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff01.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff29.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff42.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff35.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff41.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff43.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff44.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff45.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff42.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff46.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff43.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff47.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff40.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff46.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff45.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff48.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff37.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff49.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff47.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff50.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff51.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff44.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff48.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff52.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff53.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff54.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff51.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff55.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff50.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff52.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff53.img
# Successfully downloaded ../dataset/mg_0068/f25n119/ff56.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/frame.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/frame.tab
# Successfully downloaded ../dataset/mg_0068/f25n119/ff49.img
# Successfully downloaded ../dataset/mg_0068/f25n119/geom.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/geom.tab
# Successfully downloaded ../dataset/mg_0068/f25n119/ff55.img
# Successfully downloaded ../dataset/mg_0068/f25n119/hist.lbl
# Successfully downloaded ../dataset/mg_0068/f25n119/ff56.img
# Successfully downloaded ../dataset/mg_0068/f25n119/hist.tab
# Successfully downloaded ../dataset/mg_0068/f25n119/ff54.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff06.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff05.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff04.img
# Successfully downloaded ../dataset/mg_0068/f25s131/browse.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff07.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff01.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff09.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff02.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff08.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff03.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff10.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff06.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff05.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff13.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff12.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff15.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff14.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff19.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff18.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff22.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff20.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff24.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff11.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff21.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff17.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff25.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff26.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff27.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff31.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff23.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff28.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff34.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff33.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff30.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff29.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff35.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff32.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff36.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff39.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff40.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff41.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff37.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff42.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff38.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff43.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff44.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff39.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff42.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff43.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff16.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff45.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff44.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff46.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff45.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff47.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff48.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff49.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff46.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff50.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff48.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff51.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff52.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff50.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff51.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff53.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff54.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff52.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff55.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/ff53.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff47.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff54.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff56.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/frame.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/frame.tab
# Successfully downloaded ../dataset/mg_0068/f25s131/ff55.img
# Successfully downloaded ../dataset/mg_0068/f25s131/geom.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/hist.lbl
# Successfully downloaded ../dataset/mg_0068/f25s131/hist.tab
# Successfully downloaded ../dataset/mg_0068/f25s131/geom.tab
# Successfully downloaded ../dataset/mg_0068/f25s131/ff56.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff40.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff41.img
# Successfully downloaded ../dataset/mg_0068/f25s131/ff49.img
# Successfully downloaded ../dataset/mg_0068/f30s142/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff06.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff05.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff04.img
# Successfully downloaded ../dataset/mg_0068/f30s142/browse.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff03.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff01.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff08.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff09.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff10.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff06.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff11.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff05.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff12.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff02.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff14.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff13.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff07.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff16.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff15.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff18.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff20.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff21.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff23.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff24.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff26.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff22.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff27.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff29.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff28.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff30.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff31.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff32.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff25.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff34.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff35.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff36.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff39.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff40.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff41.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff40.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff42.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff41.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff19.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff37.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff43.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff42.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff44.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff33.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff45.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff46.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff43.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff39.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff47.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff17.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff48.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff45.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff49.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff50.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff48.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff47.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff38.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff51.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff52.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff53.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff50.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff54.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff55.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/ff51.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff53.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff44.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff56.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/frame.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/frame.tab
# Successfully downloaded ../dataset/mg_0068/f30s142/ff55.img
# Successfully downloaded ../dataset/mg_0068/f30s142/geom.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/geom.tab
# Successfully downloaded ../dataset/mg_0068/f30s142/hist.lbl
# Successfully downloaded ../dataset/mg_0068/f30s142/hist.tab
# Successfully downloaded ../dataset/mg_0068/f30s142/ff56.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff54.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff52.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff49.img
# Successfully downloaded ../dataset/mg_0068/f30s142/ff46.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff05.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff03.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff06.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff01.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff06.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/browse.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff02.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff04.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff08.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff09.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff10.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff12.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff11.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff13.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff14.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff15.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff05.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff17.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff07.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff18.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff16.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff19.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff20.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff22.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff23.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff24.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff25.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff21.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff26.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff29.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff28.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff30.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff31.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff32.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff27.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff33.img
# Successfully downloaded ../dataset/mg_0068/f35s143/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f35s143/ff34.img
# ...
# Successfully downloaded ../dataset/mg_0068/f40s145/ff54.img
# Successfully downloaded ../dataset/mg_0068/f40s145/hist.tab
# Successfully downloaded ../dataset/mg_0068/f40s145/ff56.img
# Successfully downloaded ../dataset/mg_0068/f40s145/hist.lbl
# Successfully downloaded ../dataset/mg_0068/f40s145/ff51.img
# Successfully downloaded ../dataset/mg_0068/f40s145/ff55.img
# Successfully downloaded ../dataset/mg_0068/f40s145/ff44.img
# Successfully downloaded ../dataset/mg_0068/f40s145/ff42.img
# Successfully downloaded ../dataset/mg_0068/f40s145/ff52.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff05.lblSuccessfully downloaded ../dataset/mg_0068/f45s218/ff06.lbl
#
# Successfully downloaded ../dataset/mg_0068/f45s218/browse.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff01.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff04.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff02.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff03.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff07.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff05.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff08.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff09.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff06.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff10.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff12.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff11.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff15.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff14.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff18.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff17.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff13.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff21.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff20.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff22.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff24.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff23.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff25.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff31.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff29.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff32.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff33.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff34.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff35.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff19.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff37.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff39.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff27.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff38.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff40.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff39.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff41.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff16.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff40.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff42.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff43.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff41.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff44.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff42.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff45.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff43.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff36.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff46.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff44.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff47.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff48.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff28.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff49.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff48.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff50.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff51.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff47.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff46.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff50.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff52.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff53.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff26.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff54.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff51.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff55.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff53.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff56.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/frame.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/frame.tab
# Successfully downloaded ../dataset/mg_0068/f45s218/ff54.img
# Successfully downloaded ../dataset/mg_0068/f45s218/geom.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/ff56.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff30.img
# Successfully downloaded ../dataset/mg_0068/f45s218/hist.lbl
# Successfully downloaded ../dataset/mg_0068/f45s218/hist.tab
# Successfully downloaded ../dataset/mg_0068/f45s218/geom.tab
# Successfully downloaded ../dataset/mg_0068/f45s218/ff45.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff49.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff55.img
# Successfully downloaded ../dataset/mg_0068/f45s218/ff52.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff02.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff03.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff04.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/browse.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff01.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff06.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff05.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/browse.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff07.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff01.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff03.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff04.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff08.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff06.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff05.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff07.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff08.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff09.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff10.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff12.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff11.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff13.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff09.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff02.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff10.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff14.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff15.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff16.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff11.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff17.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff13.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff15.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff19.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff12.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff18.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff17.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff20.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff21.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff19.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff22.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff18.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff20.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff23.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff24.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff22.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff21.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff25.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff26.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff27.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff25.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff24.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff14.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff26.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff28.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff29.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff30.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff31.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff29.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff30.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff32.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff33.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff31.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff32.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff34.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff35.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff36.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff34.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff37.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff36.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff38.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff37.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff39.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff35.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff33.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff39.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff40.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff41.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff40.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff42.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff16.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff41.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff43.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff44.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff45.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff42.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff43.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff46.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff27.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff45.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff47.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff23.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff48.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff49.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff47.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff28.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff50.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff48.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff46.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff51.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff50.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff52.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff53.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff44.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff54.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff52.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff38.imgSuccessfully downloaded ../dataset/mg_0068/f65n102/ff51.img
#
# Successfully downloaded ../dataset/mg_0068/f65n102/ff55.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/frame.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff56.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff49.img
# Successfully downloaded ../dataset/mg_0068/f65n102/frame.tab
# Successfully downloaded ../dataset/mg_0068/f65n102/geom.lbl
# Successfully downloaded ../dataset/mg_0068/f65n102/ff53.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff54.img
# Successfully downloaded ../dataset/mg_0068/f65n102/geom.tab
# Successfully downloaded ../dataset/mg_0068/f65n102/hist.tabSuccessfully downloaded ../dataset/mg_0068/f65n102/hist.lbl
#
# Successfully downloaded ../dataset/mg_0068/f65n102/ff55.img
# Successfully downloaded ../dataset/mg_0068/f65n102/ff56.img
# Successfully downloaded ../dataset/mg_0068/index/contents.tab
# Successfully downloaded ../dataset/mg_0068/index/mcumdir.lbl
# Successfully downloaded ../dataset/mg_0068/index/contents.lbl
# Successfully downloaded ../dataset/mg_0068/index/mcumdir.tab
# Successfully downloaded ../dataset/mg_0068/label/c3midrds.lblSuccessfully downloaded ../dataset/mg_0068/label/c1midrds.lbl
#
# Successfully downloaded ../dataset/mg_0068/label/dsmapc3.lbl
# Successfully downloaded ../dataset/mg_0068/label/c2midrds.lbl
# Successfully downloaded ../dataset/mg_0068/label/dsmapf.lbl
# Successfully downloaded ../dataset/mg_0068/label/dsmapc2.lbl
# Successfully downloaded ../dataset/mg_0068/label/dsmapc1.lbl
# Successfully downloaded ../dataset/mg_0068/label/fbidrds.lbl
# Successfully downloaded ../dataset/mg_0068/label/dsmapp.lbl
# Successfully downloaded ../dataset/mg_0068/label/catalog.lbl
# Successfully downloaded ../dataset/mg_0068/label/fmidrds.lblSuccessfully downloaded ../dataset/mg_0068/label/spmidrds.lbl
#
# Successfully downloaded ../dataset/mg_0068/label/npmidrds.lbl

# %%
######################################################################
# --------------------------------------------------------
# Created by Gerard Gallardo i Peres
# ---------------------------------------------------------
# Objective: Function to read Magellan Full Resolution Mosaicked
# Image Data records (F-MIDR), as well as compressed versions (C-MIDR)
#
#
# ----------------------------------------------------------
# Authors:   Gerard Gallardo / Imperial College London
#
# Reviewer:  --   /
# Last rev.: --   /
#
######################################################################
            #######            #######   #############################
###      ##########    ###############   #############################
###      ##########    ###############   #############################
###      ##########    ###############   #############################
            #######            #######           #####################
######################################################################

import numpy as np
import cnf
import chd
import math
from scipy.signal import savgol_filter


def read_mgn_SAR_img(path, cnf_data, table):

    # path = "C:/Users/Gerard/ESPE/Q4/Thesis + Special course/Data/Magellan/Idunn Mons/mg_0029/f45s218/"
    # cnf_data = vars(cnf.cnf())
    # table = vars(chd.table_muhleman_c1())

    # Matrix initialization

    pi = np.pi
    Data_info = {}

    Data_img_original = []
    Data_img_original_aux = []

    Data_img_dB_corrected = []
    Data_img_dB_corrected_aux = []

    Data_img_corrected = []
    Data_img_corrected_aux = []

    lat_matrix = []
    lat_matrix_aux2 = []
    lon_matrix = []
    lon_matrix_aux = []
    lon_matrix_aux2 = []

    inc_matrix_aux_2 = []
    inc_matrix_aux = []
    inc_matrix = []

    # SAR data initialization

    lbl1 = path.find("c1")
    lbl2 = path.find("mg_")

    if lbl1 != -1:
        lbl_aux = 'c1f'
        Data_info["type"] = "C1-MIDR"
        Data_info["mosaic"] = path[lbl2+8:lbl2+15]
    else:
        lbl_aux = 'ff'
        Data_info["type"] = "F-MIDR"
        Data_info["mosaic"] = path[lbl2+8:lbl2+15]

    Data_info["disk"] = path[lbl2:lbl2+7]

    # generate polyfits (9th degree) of the entire table values, before iteration
    lats = table["lat"]
    incs = table["inc"]
    factors = table["factor"]
    inc_interp = np.polyfit(lats, incs, 9) 
    fact_interp = np.polyfit(lats, factors, 9)

    for i in range(1, cnf_data["mgn"].framelet_num+1):

        if i < 10:
            fid = open(path+lbl_aux+"0"+str(i)+".img", "rb")
        else:
            fid = open(path+lbl_aux+str(i)+".img", "rb")


        headerendpos_ascii = fid.tell()
        header = str(fid.readline().rstrip())
        # header=fid.fgetl()

        lat_init_idx = header.find("LAT_UL")
        length_aux_idx = header.find("LON_UL")
        lat_UL = float(header[(lat_init_idx+7):(length_aux_idx-3)])
        lat_end_idx = header.find("LAT_LR")
        length_aux_idx = header.find("LON_LR")
        lat_LR = float(header[(lat_end_idx+7):(length_aux_idx-3)])

        lon_init_idx = header.find("LON_UL")
        length_aux_idx = header.find("LAT_LL")
        lon_UL = float(header[(lon_init_idx+7):(length_aux_idx-3)])
        lon_end_idx = header.find("LON_LR")
        length_aux_idx = header.find("PROJ_LON")
        lon_LR = float(header[(lon_end_idx+7):(length_aux_idx-3)])

        Data_info["Middle_lat"] = lat_LR + (lat_UL - lat_LR)/2
        Data_info["Middle_lon"] = lon_LR + (lon_UL - lon_LR)/2

        PIXSIZ_idx = header.find("PIXSIZ")
        length_idx_aux = header.find("PRODUCT")
        PIXSIZ_SAR = float(header[(PIXSIZ_idx+7):(length_idx_aux-2)])

        Data_info["PIXSIZ"] = PIXSIZ_SAR

        if cnf_data["mgn"].SAR_projection == "sinus":

            PROJSAMP_idx = header.find("PROJSAMP")
            if header[PROJSAMP_idx+9] == '0':
                PROJSAMP = 0
            else:
                PROJSAMP = float(header[(PROJSAMP_idx+9):(PROJSAMP_idx+14)])

            SPECLINE_idx = header.find("SPECLINE")

            if header[SPECLINE_idx+9] == '0':
                SPECLINE = 0
            else:
                SPECLINE = float(header[(SPECLINE_idx+9):(SPECLINE_idx+15)])

            PROJ_LON_idx = header.find("PROJ_LON")
            PROJ_LON = float(header[(PROJ_LON_idx+9):(SPECLINE_idx-3)])

            d = 6051000/PIXSIZ_SAR

            x_aux = np.linspace(1, 1024, 1024)
            y_aux = np.linspace(1, 1024, 1024)


            lon_matrix_aux = np.zeros((1024, 1024))
            lat_col = (y_aux.transpose() + 0.5 - SPECLINE)/-d*180/pi
            lat_matrix_aux = np.tile(lat_col, (1024, 1))
            for k in range(0, len(x_aux)):
                lon_matrix_aux[:, k] = ((x_aux[k]+0.5-PROJSAMP)/(np.cos(lat_col * pi/180)*d)*180/pi + PROJ_LON)
            lon_matrix_aux = np.where(lon_matrix_aux < 0, 360 + lon_matrix_aux, lon_matrix_aux)
            # lon_row = lon_row.reshape(1,len(lon_row))
            # if k == 0:
            #     lon_matrix_aux = lon_row
            # else:
            #     lon_matrix_aux = np.concatenate((lon_matrix_aux,lon_row), axis=0)
            # for k in range(0,len(x_aux)):
            #     if lon_row[0,k-1].any() < 0:
            #         lon_row[0,k-1] = 360 + lon_row[0,k-1]

        if cnf_data["mgn"].SAR_projection == "linear":

            lat_col = np.flip(np.linspace(lat_LR, lat_UL, 1024))
            lat_matrix_aux = np.tile(lat_col, (1024, 1))

            lon_row = np.flip(np.linspace(lon_LR, lon_UL, 1024))
            lon_matrix_aux = np.tile(lon_row, (1024, 1))

        reading_pos = fid.seek(1050624 - 1024 * 1024)  # file length - the size of the image in uint8 bytes
        image = np.fromfile(fid, "uint8", 1048576, "")
        image = image.reshape(1024, 1024)

        # inc_col = np.zeros(1024)
        # factor_col = np.zeros(1024)
        # for jj in range(0,1024):
        
            # matrix_aux = np.absolute(lat_matrix_aux[0,jj] - table["lat"])
            # idx_aux_lat = matrix_aux.argmin() 
            # if table["lat"][idx_aux_lat] > lat_matrix_aux[0,jj]:
                # interp_factor = (lat_matrix_aux[0,jj] - table["lat"][idx_aux_lat - 1])/(table["lat"][idx_aux_lat] - table["lat"][idx_aux_lat - 1])
                # inc_col[jj] = table["inc"][idx_aux_lat] + (table["inc"][idx_aux_lat] - table["inc"][idx_aux_lat - 1])*interp_factor
                # factor_col[jj] = table["factor"][idx_aux_lat] + (table["factor"][idx_aux_lat] - table["factor"][idx_aux_lat - 1])*interp_factor
            # else:
                # interp_factor = (table["lat"][idx_aux_lat + 1] - lat_matrix_aux[0,jj])/(table["lat"][idx_aux_lat + 1] - table["lat"][idx_aux_lat])
                # inc_col[jj] = table["inc"][idx_aux_lat] + (table["inc"][idx_aux_lat + 1] - table["inc"][idx_aux_lat])*interp_factor
                # factor_col[jj] = table["factor"][idx_aux_lat] + (table["factor"][idx_aux_lat + 1] - table["factor"][idx_aux_lat])*interp_factor          

        # inc_interp = np.polyfit(lat_col,inc_col,7) # fit polynomial of degree 7
        # fact_interp = np.polyfit(lat_col,factor_col,7) # fit polynomial of degree 7
        # factor_matrix = np.tile(factor_col,(1024,1))
        # inc_matrix_aux = np.tile(factor_col,(1024,1))
        # inc_matrix_aux = 0.00008*lat_matrix_aux**3 - 0.0127*lat_matrix_aux**2 + 0.1825*lat_matrix_aux + 45.665 # Quantitative Analysis of Venus Radar Backscatter Data in ArcGIS, 2005 First, the best-fit approximation used creates an error that is everywhere < 2%, use for low latitudes
        # inc_matrix_aux = inc_interp[0]*lat_matrix_aux**(7) + inc_interp[1]*lat_matrix_aux**(6) +inc_interp[2]*lat_matrix_aux**(5) +inc_interp[3]*lat_matrix_aux**(4) + inc_interp[4]*lat_matrix_aux**(3) + inc_interp[5]*lat_matrix_aux**(2) + inc_interp[6]*lat_matrix_aux + inc_interp[7] #Use for high latitudes (away from equator)
        # factor_matrix = fact_interp[0]*lat_matrix_aux**(7) + fact_interp[1]*lat_matrix_aux**(6) +fact_interp[2]*lat_matrix_aux**(5) +fact_interp[3]*lat_matrix_aux**(4) + fact_interp[4]*lat_matrix_aux**(3) + fact_interp[5]*lat_matrix_aux**(2) + fact_interp[6]*lat_matrix_aux + fact_interp[7] #Quantitative Analysis of Venus Radar Backscatter Data in ArcGIS, 2005 First, the best-fit approximation used creates an error that is everywhere < 2%.

        inc_matrix_aux = inc_interp[0]*lat_matrix_aux**(9) + inc_interp[1] * lat_matrix_aux**(8) + inc_interp[2] * lat_matrix_aux**(7) + inc_interp[3]*lat_matrix_aux**(6) + inc_interp[4]*lat_matrix_aux**(5) + inc_interp[5]*lat_matrix_aux**(4) + inc_interp[6]*lat_matrix_aux**(3) + inc_interp[7]*lat_matrix_aux**(2) + inc_interp[8]*lat_matrix_aux + inc_interp[9]
        factor_matrix = fact_interp[0]*lat_matrix_aux**(9) + fact_interp[1] * lat_matrix_aux**(8) + fact_interp[2] * lat_matrix_aux**(7) + fact_interp[3]*lat_matrix_aux**(6) + fact_interp[4]*lat_matrix_aux**(5) + fact_interp[5]*lat_matrix_aux**(4) + fact_interp[6]*lat_matrix_aux**(3) + fact_interp[7]*lat_matrix_aux**(2) + fact_interp[8]*lat_matrix_aux + fact_interp[9]

        # if table["type"] == "left-looking":
        #     inc_matrix_aux = 0.00008*lat_matrix_aux**(3) - 0.0127 * lat_matrix_aux**(2) + 0.1825*lat_matrix_aux + 45.665 #Quantitative Analysis of Venus Radar Backscatter Data in ArcGIS, 2005 First, the best-fit approximation used creates an error that is everywhere < 2%.
        # if table["type"] == "right-looking":
        #     inc_matrix_aux = np.tile(inc_col,(1024,1))

        image_sig0_aux = 10**(0.1*(- 20 + (image - 1)/5))
        image_sig0_aux2 = np.multiply(image_sig0_aux, (0.0118*np.cos((inc_matrix_aux + 0.5) * pi/180)))
        image_sig0_aux3 = (np.sin((inc_matrix_aux+0.5)*pi/180)+0.111*np.cos((inc_matrix_aux + 0.5)*pi/180))**3
        image_sig0 = np.divide(image_sig0_aux2, image_sig0_aux3)
        image_sig0_dB = -20+(image-1)/5 + factor_matrix
        # image_sig0_dB = 10*np.log10(image_sig0)

        # lat_matrix_aux = lat_matrix_aux.transpose()
        lon_matrix_aux = lon_matrix_aux.transpose()
        # inc_matrix_aux = inc_matrix_aux.transpose()
        image = image.transpose()
        image_sig0 = image_sig0.transpose()
        image_sig0_dB = image_sig0_dB.transpose()

        if i == 1 or i % 8 == 1:
            Data_img_original_aux = image
            Data_img_corrected_aux = image_sig0
            Data_img_dB_corrected_aux = image_sig0_dB
            lat_matrix_aux2 = lat_matrix_aux
            lon_matrix_aux2 = lon_matrix_aux
            inc_matrix_aux2 = inc_matrix_aux
        else:
            Data_img_original_aux = np.vstack((Data_img_original_aux, image))
            Data_img_corrected_aux = np.vstack((Data_img_corrected_aux, image_sig0))
            Data_img_dB_corrected_aux = np.vstack((Data_img_dB_corrected_aux, image_sig0_dB))
            lat_matrix_aux2 = np.vstack((lat_matrix_aux2, lat_matrix_aux))
            lon_matrix_aux2 = np.vstack((lon_matrix_aux2, lon_matrix_aux))
            inc_matrix_aux2 = np.vstack((inc_matrix_aux2, inc_matrix_aux))
    
        lon_matrix_aux = []

        size_aux = np.shape(Data_img_original_aux)
        if np.floor(size_aux[0]/1024) == 8 and i == 8:
            Data_img_original = Data_img_original_aux
            Data_img_corrected = Data_img_corrected_aux
            Data_img_dB_corrected = Data_img_dB_corrected_aux
            lat_matrix = lat_matrix_aux2
            lon_matrix = lon_matrix_aux2
            inc_matrix = inc_matrix_aux2    
            Data_img_original_aux = []
            Data_img_dB_corrected_aux = []
            Data_img_corrected_aux = []
            lat_matrix_aux2 = []
            lon_matrix_aux2 = []
            inc_matrix_aux2 = []
        elif np.floor(size_aux[0]/1024) == 8 and i != 8:
            Data_img_original = np.hstack((Data_img_original, Data_img_original_aux))
            Data_img_corrected = np.hstack((Data_img_corrected, Data_img_corrected_aux))
            Data_img_dB_corrected = np.hstack((Data_img_dB_corrected, Data_img_dB_corrected_aux))
            lat_matrix = np.hstack((lat_matrix, lat_matrix_aux2))
            lon_matrix = np.hstack((lon_matrix, lon_matrix_aux2))
            inc_matrix = np.hstack((inc_matrix, inc_matrix_aux2))
            Data_img_original_aux = []
            Data_img_dB_corrected_aux = []
            Data_img_corrected_aux = []
            lat_matrix_aux2 = []
            lon_matrix_aux2 = []
            inc_matrix_aux2 = []

        fid.close()

    Data_img_original = Data_img_original.transpose()
    Data_img_dB_corrected = Data_img_dB_corrected.transpose()
    Data_img_corrected = Data_img_corrected.transpose()
    lat_matrix = lat_matrix.transpose()
    lon_matrix = lon_matrix.transpose()
    inc_matrix = inc_matrix.transpose()
    lat_matrix = np.sort(lat_matrix, axis=1)
    lon_matrix = np.sort(lon_matrix, axis=0)

    inc_matrix = inc_matrix[np.flip(np.argsort(inc_matrix[:, 0])), :] # Find a sorted order of the given labels

    if cnf_data["mgn"].SAR_projection == "sinus":
        
        lon_matrix[lon_matrix < 0] = np.nan
        lon_matrix[lon_matrix > 360] = np.nan

    # In case no specific 1024x1024 framelet is selected, use the whole lat/lon array of the framelet
    # linearizing from the corners, to avoid the discontinuity at the edges of the framelets

    if cnf_data['mgn'].framelet_selection == 0:
    # lon_matrix = savgol_filter(lon_matrix, 101, 3,axis=1)
    # lat_matrix = savgol_filter(lat_matrix, 101, 3,axis=0)
        lat_matrix_aux = np.flip(np.linspace(lat_matrix[-1, -1], lat_matrix[0, 0], 7168))
        lat_matrix = np.tile(lat_matrix_aux, (8192, 1)).T
        lon_matrix_aux = np.flip(np.linspace(lon_matrix[-1, -1], lon_matrix[0, 0], 8192))
        lon_matrix = np.tile(lon_matrix_aux, (7168, 1))

    # Select a specific framelet within the loaded MIDR product, if required

    if cnf_data['mgn'].framelet_selection != 0:
        framelet_row = (cnf_data['mgn'].framelet_selection - 1) // 8
        framelet_col = (cnf_data['mgn'].framelet_selection - 1) - framelet_row * 8

        Data_img_original = Data_img_original[
            framelet_row * 1024: framelet_row * 1024 + 1024,
            framelet_col * 1024: framelet_col * 1024 + 1024
        ]
        Data_img_dB_corrected = Data_img_dB_corrected[
            framelet_row * 1024: framelet_row * 1024 + 1024,
            framelet_col * 1024: framelet_col * 1024 + 1024
        ]
        Data_img_corrected = Data_img_corrected[
            framelet_row * 1024: framelet_row * 1024 + 1024,
            framelet_col * 1024: framelet_col * 1024 + 1024
        ]
        inc_matrix = inc_matrix[
            framelet_row * 1024: framelet_row * 1024 + 1024,
            framelet_col * 1024: framelet_col * 1024 + 1024
        ]
        lat_matrix = lat_matrix[
            framelet_row * 1024: framelet_row * 1024 + 1024,
            framelet_col * 1024: framelet_col * 1024 + 1024
        ]
        lon_matrix = lon_matrix[
            framelet_row * 1024: framelet_row * 1024 + 1024,
            framelet_col * 1024: framelet_col * 1024 + 1024
        ]
    

    Data_info["corner_UL"] = [lat_matrix[0, 0], lon_matrix[0, 0]]
    Data_info["corner_LR"] = [lat_matrix[-1, -1], lon_matrix[-1, -1]]

    return Data_img_original, Data_img_corrected, Data_img_dB_corrected, lat_matrix, lon_matrix, inc_matrix, Data_info

# %%
from setuptools import setup
import numpy as np
import cnf
import chd
import math
from scipy.signal import savgol_filter

# %%
path = "../dataset/mg_0068/f10s115/"
cnf_data = vars(cnf.cnf())
table = vars(chd.table_muhleman_c1())
Data_img_original, Data_img_corrected, Data_img_dB_corrected, lat_matrix, lon_matrix, inc_matrix, Data_info=read_mgn_SAR_img(path, cnf_data, table)

# %%
#visualising Data
import seaborn as sns
sns.heatmap((Data_img_dB_corrected), annot=True, cmap='viridis')
